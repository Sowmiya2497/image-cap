# %%
##Mounts all Google Driver folders and authenticates

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
## Change to project directory
import os
os.chdir('/content/drive/My Drive/Image_Captioning/Implementation')
# !ls

# %%
## Run training for weighting strategy 1

# !python2 "driver_weight_calculation_1.py"

# %%
## Run training for weighting strategy 2

# !python2 "driver_weight_calculation_2.py"
